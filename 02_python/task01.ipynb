# %%
# 名前
name = "坂元雄大"
# 年齢
age = 40
# 自己紹介
print(f"はじめまして、 {name} と申します。", f"年齢は {age} 歳です。来年は {age + 1} 歳になります。", "よろしくお願いします。", sep="\n")
# Out:
# はじめまして、 坂元雄大 と申します。
# 年齢は 40 歳です。来年は 41 歳になります。
# よろしくお願いします。
