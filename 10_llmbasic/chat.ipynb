# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint
import tiktoken
from tiktoken.core import Encoding

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("こんにちは！")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# tokens_count=2
# tokens=[95839, 3393]
# 言語モデルを効果的に使うためのポイントはいくつかあります。以下にいくつかの重要な点を挙げます：
#
# 1. **明確な指示を与える**: モデルに対して具体的で明確な質問や指示をすることで、より関連性の高い応答を得ることができます。具体的な情報や文脈を提供することが重要です。
#
# 2. **コンテキストの提供**: モデルは文脈を理解する能力がありますが、それを最大限に活かすためには、関連する情報や背景を提供することが重要です。この情報は、特に複雑な質問や要望において有効です。
#
# 3. **出力の確認と編集**: 言語モデルが提供する情報は必ずしも正確とは限らないため、結果を確認し、必要に応じて編集や修正を行うことが大切です。
#
# 4. **トライアンドエラー**: 望む結果を得るためには、試行錯誤を行うことも重要です。異なる質問の仕方やフォーマットを試みることで、より良い応答が得られることがあります。
#
# 5. **継続的な学習**: モデルの使用を通じて、どのような質問や入力が効果的であったかを学び、次回に活かすことができます。
#
# 6. **倫理的な使用**: 言語モデルを使用する際には、生成されるコンテンツが倫理的であること、また他者に対して害を及ぼさないように注意を払うことが重要です。
#
# 7. **用途に応じた設定**: モデルの設定やパラメータを調整し、特定の用途（例：クリエイティブな文章生成、情報の要約など）に最適化することができます。
#
# これらのポイントを意識することで、言語モデルをより効果的に活用し、有益な結果を得ることができるでしょう。
